# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/1275/1*7bnLKsChXq94QjtAiRn40w.png)

# %% [markdown]
# # What is the Iris Dataset
#
# ### Fisher's Iris data Set
# The Iris flower data set or Fisher's Iris data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems as an example of linear discriminant analysis.It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species.Two of the three species were collected in the Gaspé Peninsula "all from the same pasture, and picked on the same day and measured at the same time by the same person with the same apparatus".
#
# ### What is the dataset used for?
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters. Based on the combination of these four features, Fisher developed a linear discriminant model to distinguish the species from each other.

# %% [markdown]
# #  Importing required Modules
# Current version of seaborn generates a bunch of warnings that will be ignored with import warnings and warnings.filterwarnings('always'), warnings.filterwarnings('ignore'). </br> Import numpy for mathematical operations such as arrays and random package functions. Import panda for handling data. Import matplotlib.plyplot for plotting graphs and import seaborn for handling data visulaisation.

# %%
import warnings # current version of seaborn generates a bunch of warnings that will be ignored
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np # handles mathemathical operations
import pandas as pd # handling data 
import matplotlib.pyplot as plt# plotting graphs 
import seaborn as sns  # handles data visualisation

# %% [markdown]
# ### load Iris Flower dataset
# Here I will load the Iris dataset from a raw github url and display the first 20 values.

# %%
# load Iris Flower dataset
IrisData = pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')
# display the first 20 values in the dataset
IrisData.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# ### Structure of the Data Set
# This shows the exact size of each class of flower in the dataset.

# %%
#This shows the exact size of each class of flower in the dataset
IrisData.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# This shows the size of the This shows the size of the dataset or structure. The dataset has 150 rows and 5 columns

# %%
#This shows the size of the dataset or structure 
# The dataset has 150 rows and 5 columns
IrisData.shape
# Out:
# (150, 5)

# %% [markdown]
# Since the dataset is already indexed we can drop the id column. I am using a new csv file so I dont need to drop the the first column.

# %%
# IrisData.drop(['Id'],axis=1,inplace=True)

# %%
#This shows the statistical quantities  such as mean std and so on
IrisData.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Display the last 5 values of the dataset with tail function

# %%
# This shows the last 5 values of the dataset
IrisData.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# Show the info of each variable in the dataset such as length, type and memory

# %%
# This tells info of each variable in the dataset such as length, type and memory
IrisData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ### Show the Dataset in a plots and Grapghs

# %% [markdown]
# - First make a scatterplot of the iris data inside the scatter func put the variables such as the Sepal Length and Sepal Width
# - label the x axis to Sepal Length from sepal_length
# - label the y axis to Sepal Width from sepal_width
# - Set the title

# %%
# make a scatterplot of the iris data
IrisData.plot(kind='scatter',x='sepal_length', y='sepal_width')
#label the x axis 
plt.xlabel('Sepal Length')
#label the y axis 
plt.ylabel('Sepal Width')
# Set the title
plt.title('Scatter plot of Sepal length & width ')
# Out:
# Text(0.5,1,'Scatter plot of Sepal length & width ')

# %% [markdown]
# ### Plot a best fit line through the dataset
# First instialise the variables, then Find the best fit line using numpys polyfit function.
# - After Plot the best fit line.
# - y = mx+c to find y this is the line equation and plot it.
# - Set the x label to the petal Lenth.
# - Set the y label to petal Width and tiltle to Petal length & width scatter plot with best fit line.
# - Lastly the legend should be of size 9.5 and location = best.

# %%
# plot the line 
petalLength = IrisData.petal_length    
petalWidth =  IrisData.petal_width     
#Find the best fit line using numpys polyfit function
bestFitLine = np.polyfit(petalLength, petalWidth, 1)

# Plot the best fit line.
plt.scatter(petalLength, petalWidth, marker='+', label='Petal length & width points')
# y = mx+c to find y.
plt.plot(petalLength, bestFitLine[0] * petalLength + bestFitLine[1], label='line')

# Set label,title,legend then display the plot.
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('Petal length & width scatter plot with best fit line.')
plt.legend(loc='best', fontsize=9.5)
plt.show()

# %% [markdown]
#  ### The graphs explain why is it diﬃcult in writing an algorithm to separate the three classes of iris

# %% [markdown]
# ### PairPlot
#
# #### What is PairPlot
# Plot pairwise relationships in a dataset.
#
# By default, this function will create a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column. The diagonal Axes are treated differently, drawing a plot to show the univariate distribution of the data for the variable in that column.
#
# A useful seaborn plot is the pairplot, which shows the bivariate relation between each pair of features.From the pairplot, we'll see that the Iris-setosa species is separataed from the other two across all feature combinations.

# %%
#pairplot 
sns.set(style="ticks", color_codes=True)
# palette Use a different color palette
sns.pairplot(IrisData, hue='species',palette="colorblind", markers=["o", "s", "D"])
# show the pair plot
plt.show()

# %% [markdown]
# I am plotting a another pairplot to show how you can change the markers and also the type of plotting. In this case I am ploting a line plot rather than the histagram.

# %%
# by default the pairplot shows histagram but we can updtae the parameters to show other things
sns.pairplot(IrisData, hue='species',markers =['+','*','o'],diag_kind='kde')
plt.show()

# %% [markdown]
# ### Conclusion
# - If you look at the above graph setosa specie is very distinguishable from the other two species
# - The Versiclolor and Virginica overlap each other
# - it is diﬃcult in writing an algorithm to separate the three classes of iris because of the two species overlapping
# - It is very hard to differentiate between the species thus making it hard to write a algorithm.

# %% [markdown]
# ### VISUALIZING THE DISTRIBUTIION OF FEATURES.
# This method here shows the statistical quantities being plotted on to a graph.
# This shows the statistical quantities  such as mean std and so on

# %%
def plot(feature):
    fig,axes=plt.subplots(1,2)
    sns.boxplot(data=IrisData,x=feature,ax=axes[0])#box plot of dataset 
    sns.distplot(a=IrisData[feature],ax=axes[1],color='#ff3333')
    fig.set_size_inches(15,5)
#This shows the statistical quantities  such as mean std and so on
IrisData.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# I have created the function in the above column and I will pass the pass the variables into the func, to draw each of them.

# %%
#this just plots the different variables passed to the function
plot('sepal_length')
plot('sepal_width')
plot('petal_length')
plot('petal_width')
# Out:
# C:\Users\naqia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\naqia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\naqia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\naqia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Box Plot
# A simple way of representing statistical data on a plot in which a rectangle is drawn to represent the second and third quartiles, usually with a vertical line inside to indicate the median value. The lower and upper quartiles are shown as horizontal lines either side of the rectangle.

# %% [markdown]
#  Make a boxplot with Pandas on each feature split out by species, We can look at an individual feature in Seaborn through a boxplot.

# %%
# make a boxplot with Pandas on each feature split out by species
## We can look at an individual feature in Seaborn through a boxplot
ax = IrisData.boxplot(by='species', figsize=(18,9))
plt.show()

# %% [markdown]
# ### FactorPlot
# A factor plot is simply the same plot generated for different response and factor variables and arranged on a single page. The underlying plot generated can be any univariate or bivariate plot. The scatter plot is the most common application.
# ###### This show the 3 classes overlapping. We can look at an individual feature in Seaborn through a factorplot

# %%
#This show the 3 classes overlapping 
# # We can look at an individual feature in Seaborn through a factorplot
sns.factorplot('sepal_length', data=IrisData, hue='species', kind='count', size=(8))

# %% [markdown]
# ### ViolinPlot
# A violin plot is a method of plotting numeric data. It is similar to a box plot with a rotated kernel density plot on each side.
#
# A violin plot has four layers. The outer shape represents all possible results, with thickness indicating how common. (Thus the thickest section represents the mode average.) The next layer inside represents the values that occur 95% of the time. The next layer (if it exists) inside represents the values that occur 50% of the time. The central dot represents the median average value.

# %%
# A violin plot combines the benefits of the two plots stripplot and boxplot and simplifies them
# Denser regions of the data are fatter, and sparser thiner in a violin plot
sns.violinplot(x='species',y='sepal_length', data=IrisData)
plt.show()
sns.violinplot(x='species',y='sepal_width', data=IrisData)
plt.show()
sns.violinplot(x='species',y='petal_length', data=IrisData)
plt.show()
sns.violinplot(x='species',y='petal_width', data=IrisData)
plt.show()

# %% [markdown]
# ### Links
# [Iris flower data set Wiki](https://en.wikipedia.org/wiki/Iris_flower_data_set) <br/>
# [UCI Machine Learning Repository: Iris Data Set](https://archive.ics.uci.edu/ml/datasets/iris)<br/>
# [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html) <br/>
# [Choosing color palettes](https://seaborn.pydata.org/tutorial/color_palettes.html) <br/>
# [Violin_plot](https://en.wikipedia.org/wiki/Violin_plot)<br/>
# [factplot](https://www.itl.nist.gov/div898/software/dataplot/refman1/auxillar/factplot.htm)
