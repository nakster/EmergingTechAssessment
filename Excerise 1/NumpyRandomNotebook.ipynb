# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/NumPy_logo.svg/1200px-NumPy_logo.svg.png)
# #### NumPy is the fundamental package for scientific computing with Python. It contains among other things:
#
# * A powerful N-dimensional array object
# * Sophisticated (broadcasting) functions
# * Tools for integrating C/C++ and Fortran code
# * Useful linear algebra, Fourier transform, and random number capabilities
#
# Numpy is a powerfull set of tools to perform mathematical operations of on lists of numbers. Numpy is faster than python and is builds on (and is a successor to) the successful Numeric array object. Its goal is to create the corner-stone for a useful environment for scientific computing.

# %% [markdown]
# ### Import The Library
# First, You have to import Numpy as np. This helps writing code and it's almost a standard in scientific work.

# %%
import numpy as np

# %% [markdown]
# ### The Rand Function of the random package in Numpy
#
# #### numpy.random.rand(d0, d1, ..., dn) <br />
# <mark>Parameters:</mark> d0, d1, …, dn : int, optional <br/>
# * The dimensions of the returned array, should all be positive. If no argument is given a single Python float is returned.<br/>
#
# <mark>Returns:</mark> Array of defined shape, filled with random values.

# %%
x = np.random.rand(100) #This is how you randomly fill one dimensional array with random values

# %% [markdown]
# If one value is added to the parameter  of the rand function it will generate one dimension array of random values

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
plt.hist(x) # displays the histagram of the random values generated by the rand fuction
#plt.show()
# Out:
# (array([12., 10., 11.,  9.,  8., 15.,  7., 11.,  7., 10.]),
#  array([0.00112338, 0.10070489, 0.20028639, 0.2998679 , 0.3994494 ,
#         0.49903091, 0.59861241, 0.69819392, 0.79777542, 0.89735692,
#         0.99693843]),
#  <a list of 10 Patch objects>)

# %%
y= np.random.rand(10,4) #2D Array filled with random values
y
# Out:
# array([[0.12929466, 0.41518631, 0.56271885, 0.53363265],
#        [0.28512768, 0.18391571, 0.12833063, 0.34459492],
#        [0.45263559, 0.78233477, 0.69408788, 0.25104968],
#        [0.34563404, 0.57693314, 0.82335044, 0.43368809],
#        [0.75130497, 0.44317892, 0.70329316, 0.75876934],
#        [0.46496532, 0.34818353, 0.41752287, 0.60765086],
#        [0.54782676, 0.90009275, 0.39912435, 0.82600983],
#        [0.68734466, 0.14462624, 0.49834048, 0.92152332],
#        [0.42279749, 0.56060079, 0.02055094, 0.99957642],
#        [0.86219965, 0.80344775, 0.52343367, 0.67566605]])

# %%
plt.plot(y,'b.')
plt.show()

# %%
a = np.random.rand(5,4,4) #3D Array filled with random values
a
# Out:
# array([[[0.03421514, 0.43272695, 0.15684632, 0.48492869],
#         [0.80962665, 0.67382504, 0.28932924, 0.82877206],
#         [0.56740201, 0.70855982, 0.84273724, 0.94369868],
#         [0.14177101, 0.53257276, 0.03198408, 0.79904957]],
#
#        [[0.43288519, 0.32182737, 0.86965327, 0.40985475],
#         [0.774725  , 0.15087527, 0.84812985, 0.1017022 ],
#         [0.18193287, 0.97450124, 0.81876198, 0.17156469],
#         [0.75022922, 0.28598584, 0.07034059, 0.68321242]],
#
#        [[0.99746356, 0.13141042, 0.43826627, 0.41071614],
#         [0.82956772, 0.61890796, 0.15149115, 0.32895133],
#         [0.47070629, 0.37657771, 0.80295962, 0.37767326],
#         [0.07500208, 0.45512654, 0.00940702, 0.52897443]],
#
#        [[0.41504923, 0.73295676, 0.47067954, 0.69631496],
#         [0.19160563, 0.7337727 , 0.622058  , 0.09487773],
#         [0.18611184, 0.16559619, 0.19764716, 0.00293926],
#         [0.38830289, 0.65256837, 0.90988749, 0.23081242]],
#
#        [[0.13898101, 0.48927391, 0.87355592, 0.30944042],
#         [0.82307121, 0.52166956, 0.13676869, 0.39102989],
#         [0.03297778, 0.79390875, 0.85438234, 0.42365573],
#         [0.49039844, 0.72161403, 0.11686837, 0.68519606]]])

# %%
# Displaying the 3d array of random values
a.nonzero()
z,x,y = a.nonzero()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c= 'blue')

# %% [markdown]
# #### Links
# http://www.numpy.org/ <br/>
# https://docs.scipy.org/doc/numpy-1.13.0/reference/routines.math.html <br/>
# https://www.geeksforgeeks.org/numpy-random-rand-python/ <br/>
# https://stackoverflow.com/questions/12414619/creating-a-3d-plot-from-a-3d-numpy-array <br/>
